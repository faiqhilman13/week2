# %%
import pandas as pd
import csv

# %%
df = pd.read_excel (r"C:\Users\Faiq Hilman\Downloads\ticketPrices.xlsx")
de = pd.read_csv (r"C:\Users\Faiq Hilman\Downloads\passengerData.csv")
print (de)
print (df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
de = pd.read_csv (r"C:\Users\Faiq Hilman\Downloads\passengerData.csv")
print (de)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
pd.merge (de,df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
de = pd.merge(de,df, on='TicketType')
de
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
print ("Maximum age: ", de(['Age'].max())
# Out:
#   Input In [8]
#     print ("Maximum age: ", de(['Age'].max())
#                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
de.groupby(['Age']).max()
# Out:
#        PassengerId  Survived  Pclass                                  Name  \
# Age
# 0.42           804         1       3       Thomas, Master. Assad Alexander
# 0.67           756         1       2             Hamalainen, Master. Viljo
# 0.75           645         1       3         Baclini, Miss. Helene Barbara
# 0.83           832         1       2       Richards, Master. George Sibley
# 0.92           306         1       1        Allison, Master. Hudson Trevor
# ...            ...       ...     ...                                   ...
# 70.00          746         0       2           Mitchell, Mr. Henry Michael
# 70.50          117         0       3                  Connors, Mr. Patrick
# 71.00          494         0       1             Goldschmidt, Mr. George B
# 74.00          852         0       3                   Svensson, Mr. Johan
# 80.00          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#           Sex  TicketType  Fare
# Age
# ...

# %%
col = "Age"
max_x = de.loc[de[col].idxmax()]
print ("Maximum value of column ", col, " and its corresponding row values:\n", max_x)
# Out:
# Maximum value of column  Age  and its corresponding row values:
#  PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# TicketType                                        7
# Fare                                             87
# Name: 747, dtype: object

# %%
from matplotlib import pyplot as plt
col_7 = de["Sex"]
idx_s = de[col_7 == 'female']
idx_a = idx_s[idx_s.Age.between (40,50)]
idx_f = idx_a[idx_a.Fare >= 40]
col_a = idx_f["Age"]
col_f = idx_f["Fare"]
plt.xlabel('Age')
plt.ylabel('Fare')
plt.scatter(col_a, col_f, s = 100, color = 'grey')
plt.show()

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
f4 = pd.read_csv("titanicSurvival_m.csv", encoding = 'latin-1')
de = pd.DataFrame(f4)
de[["Age", "Fare"]] = df[["Age", "Fare"]].fillna(0)
de.to_csv('C:\Users\Faiq Hilman\Downloads\passengerData.csv')
fig = plt.figure()
col_10 = df["Fare"]
col_6 = df["Age"]
plt.xlabel('Age')
plt.ylabel('Fare')
plt.scatter(col_6,col_10, s = 10, color = 'red')
plt.show()
# Out:
#   Input In [13]
#     de.to_csv('C:\Users\Faiq Hilman\Downloads\passengerData.csv')
#                                                                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
